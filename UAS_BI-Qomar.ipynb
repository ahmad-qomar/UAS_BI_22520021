# %%
# Import library yang diperlukan
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
# Upload file caesarian.csv
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-04f022a1-f6a4-4e73-b150-8a5e0c68bf9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04f022a1-f6a4-4e73-b150-8a5e0c68bf9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Mengganti 'nama_file.csv' dengan nama file dataset caesarian yang Anda miliki
file_path = 'caesarian.csv'  # Ganti dengan nama file yang sesuai
caesarian_data = pd.read_csv(file_path)

# %%
# Menampilkan beberapa baris pertama data sebagai contoh
print(caesarian_data.head())
# Out:
#   Usia;Kelahiran_ke-;Waktu_Kelahiran;Tekanan_darah;Kelainan_jantung;Caesarian
# 0                                       22;1;0;2;0;0
# 1                                       26;2;0;1;0;1
# 2                                       26;2;1;1;0;0
# 3                                       28;1;0;2;0;0
# 4                                       22;2;0;1;0;1

# %%
# Pemilihan fitur (features) dan target
features = ['Umur', 'Kelahiran_ke', 'Waktu_Kelahiran', 'Tekanan_darah', 'Kelainan_Jantung']
target = 'Caesarian'

# %%
# Menampilkan informasi atau isi dari file Excel
print(df.head())  # Menampilkan beberapa baris pertama data sebagai contoh
# Out:
#    Usia  Kelahiran_ke  Waktu_Kelahiran  Tekanan_darah  Kelainan_Jantung  \
# 0    25             1               39            120                 0
# 1    30             2               40            122                 1
# 2    35             1               38            118                 0
# 3    28             3               41            125                 0
# 4    32             2               39            120                 1
#
#    Caesarian
# 0          1
# 1          0
# 2          1
# 3          1
# 4          0

# %%
data = {
    'Usia': [25, 30, 35, 28, 32],
    'Kelahiran_ke': [1, 2, 1, 3, 2],
    'Waktu_Kelahiran': [39, 40, 38, 41, 39],
    'Tekanan_darah': [120, 122, 118, 125, 120],
    'Kelainan_Jantung': [0, 1, 0, 0, 1],
    'Caesarian': [1, 0, 1, 1, 0]
}

df = pd.DataFrame(data)

caesarian_data = pd.DataFrame(data)

# %%
# Pemilihan fitur (features) dan target
features = ['Usia', 'Kelahiran_ke', 'Waktu_Kelahiran', 'Tekanan_darah', 'Kelainan_Jantung']
target = 'Caesarian'

# %%
# Memisahkan fitur dan target
X = caesarian_data[features]
Y = caesarian_data[target]

# %%
# Standarisasi fitur
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Membagi dataset menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Pastikan jumlah tetangga tidak melebihi jumlah sampel dalam data latih
k_neighbors = min(5, len(X_train) - 1)

# %%
# Membuat model KNN dengan K=5 (atau jumlah tetangga yang sesuai)
knn_model = KNeighborsClassifier(n_neighbors=k_neighbors)
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Inisialisasi model KNN dengan k=5
knn_model = KNeighborsClassifier(n_neighbors=5)

# %%
# Melatih model KNN pada data latih
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predict pada data uji
y_pred = knn_model.predict(X_test)

# %%
# Import library untuk mengukur akurasi
from sklearn.metrics import accuracy_score

# %%
# Mengukur akurasi
accuracy = accuracy_score(y_test, y_pred)
print(f"Akurasi model KNN: {accuracy:.2f}")
# Out:
# Akurasi model KNN: 0.00

# %%
# Prediksi untuk Ibu hamil dengan Usia 25 Tahun
input_data_a = [[25, 1, 0, 1, 0]]  # # usia 25; anak ke 1: waktu kelahiran 0; Tekanan darah 1; dan Kelainan Jantung 1 ,#Ganti dengan nilai yang sesuai
input_data_a_scaled = scaler.transform(input_data_a)
prediction_a = knn_model.predict(input_data_a_scaled)
print(f"Prediksi untuk Ibu hamil dengan Usia 25 Tahun: {prediction_a[0]}")
# Out:
# Prediksi untuk Ibu hamil dengan Usia 25 Tahun: 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#Prediksi untuk Ibu hamil dengan Usia 35 Tahun
input_data_b = [[35, 1, 0, 2, 1]]  # Ganti dengan nilai yang sesuai
input_data_b_scaled = scaler.transform(input_data_b)
prediction_b = knn_model.predict(input_data_b_scaled)
print(f"Prediksi untuk Ibu hamil dengan Usia 35 Tahun: {prediction_b[0]}")
# Out:
# Prediksi untuk Ibu hamil dengan Usia 35 Tahun: 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
